# %% [markdown]
# ## Machine Learning Intern at Infopillar Solutions for November 2021 Batch
#
# ## Author : Dhaval Sunil Tharkar
#
# ## Task 4 : Housing Prices Prediction Project
#
# Project idea – The dataset has house prices of the Boston residual areas.
# The expense of the house varies according to various factors like crime rate, number of rooms,
# etc. It is a good ML project for beginners to predict prices on the basis of new data.
#
# Dataset: https://bit.ly/3uU4dtg

# %% [markdown]
# ## About Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# CRIM - per capita crime rate by town
#
# ZN - proportion of residential land zoned for lots over
# 25,000 sq.ft.
#
# INDUS - proportion of non-retail business acres per town.
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX - nitric oxides concentration (parts per 10 million)
#
# RM - average number of rooms per dwelling
#
# AGE - proportion of owner-occupied units built prior to 1940
#
# DIS - weighted distances to five Boston employment centres
#
# RAD - index of accessibility to radial highways
#
# TAX - full-value property-tax rate per $10,000
#
# PTRATIO - pupil-teacher ratio by town
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT - % lower status of the population
#
# MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import klib

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the csv file into the Variable named as df

# %%
df = pd.read_csv('boston.csv')

# %% [markdown]
# ## Exploratory Data Analysis EDA on the dataset variable df

# %%
df.head() # Shows the first five rows of the data from variable df
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.tail() # Shows the last five rows of the data from variable df
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9

# %%
df.shape # shows the shape of the data variable in tuple format
# variable_name(number of rows, number of columns)
# Out:
# (506, 15)

# %%
df.info() # Print the summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
df.describe() 
# shows the Statistical details like 
# count, mean,standard deviation, minimum value, quartile 1 i.e. 25 %, quartile 2 i.e. median or 50 %, 
# quartile 3 i.e. 75, maximum value.
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
df.columns # Displays the name of the columns from the data variable df
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df = df.drop("Unnamed: 0", axis=1)
# As the Unnamed: 0 column in the boston dataset resembles to the serial number
# of the rows inserted as it is not necessary for prediction 
# we are droping the Unnamed: 0 column  from the data set

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df.isna().sum() # Checks whether the dataset contains any null value or not 
# isna().sum() will give the sum of the null values present in the dataset
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True) # heatmap of correlation matrix
# Out:
# <AxesSubplot:>

# %%
klib.corr_plot(df, split = 'pos') # displays only the positive correlation
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df, split = 'neg') # displays only the negative correlation
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# creating histograms to visualize all the data
fig = plt.figure(figsize = (40,40))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

ax = fig.gca()
df.hist(ax = ax)
# Out:
# array([[<AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'zn'}>,
#         <AxesSubplot:title={'center':'indus'}>,
#         <AxesSubplot:title={'center':'chas'}>],
#        [<AxesSubplot:title={'center':'nox'}>,
#         <AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'dis'}>],
#        [<AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>,
#         <AxesSubplot:title={'center':'black'}>],
#        [<AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Spliting the dataset as independent variable X and dependent variable y

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
print(X)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(y)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ## Spliting the X and y variables into the train and test dataset¶

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
X_train.shape
# Out:
# (404, 13)

# %%
y_train.shape
# Out:
# (404,)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
y_test.shape
# Out:
# (102,)

# %% [markdown]
# ## Creating a RandomForest Regression Machine Learning Model with hyperparameter tunning of max_features

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(max_features = 13)
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=13)

# %%
y_pred_train = reg.predict(X_train)
y_pred_test = reg.predict(X_test)

# %% [markdown]
# ## Comparing the Actual Values of the dataset with the Predicted Values of the Random Forest Regressor Model on to the train and test dataset

# %%
op_train1 = pd.DataFrame({
    'Actual': y_train,
    'Predicted' : y_pred_train
})
op_train1
# Out:
#      Actual  Predicted
# 0      19.7     20.064
# 1      23.1     20.565
# 2      13.5     13.943
# 3      21.2     21.041
# 4      23.1     21.560
# ..      ...        ...
# 399    23.8     23.587
# 400    19.9     19.734
# 401    20.6     21.006
# 402    21.4     20.386
# 403    22.8     21.744
#
# [404 rows x 2 columns]

# %%
op_test1 = pd.DataFrame({
    'Actual': y_test,
    'Predicted' : y_pred_test
})
op_test1
# Out:
#      Actual  Predicted
# 0      28.4     25.030
# 1      31.1     29.161
# 2      23.5     25.791
# 3      26.6     28.827
# 4      19.6     18.479
# ..      ...        ...
# 97     24.4     21.115
# 98     22.6     20.614
# 99     19.8     20.295
# 100    22.2     22.667
# 101    18.6     19.773
#
# [102 rows x 2 columns]

# %%
plt.scatter(y_train,y_pred_train)

# %%
sns.regplot(y_train,y_pred_train)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(y_test,y_pred_test)

# %%
sns.regplot(y_test,y_pred_test)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
M_A_E = mean_absolute_error(y_test, y_pred_test)
M_S_E = mean_squared_error(y_test, y_pred_test)
R_M_S_E = np.sqrt(mean_squared_error(y_test, y_pred_test))
M_A_P_E = mean_absolute_percentage_error(y_test, y_pred_test)
R2_score = r2_score(y_test, y_pred_test)
n = X_test.shape[0]
p = X_test.shape[1]
num = (1-R2_score)*(n-1)
den = n-p-1

adj_r2 = 1- (num/den)

# %%
print("Mean Absolute Error : ", M_A_E)
print("Mean Square Error : ", M_S_E)
print("Root Mean Square Eror : ", R_M_S_E)
print("Mean Absolute Percentage Error : ", M_A_P_E)
print("R2 Score : ", R2_score)
print("Adjusted R2 Score : ", adj_r2)
# Out:
# Mean Absolute Error :  2.7380098039215675
# Mean Square Error :  14.863432284313726
# Root Mean Square Eror :  3.855312216191281
# Mean Absolute Percentage Error :  0.11323332025900353
# R2 Score :  0.8578760117752908
# Adjusted R2 Score :  0.8368804226057315

# %%
print('R2 Score:',r2_score(y_train, y_pred_train))
# Out:
# R2 Score: 0.9763928842195416

# %%
print('R2 Score:',r2_score(y_test, y_pred_test))
# Out:
# R2 Score: 0.8578760117752908

# %% [markdown]
# ## Random Forest Regressor works better on to the boston.csv as compare with others
#
# ## Random Forest Regressor with the Hyperparameter of max_features = 13 gives the better resultant R2 Score
#
# ## For the train dataset R2 score is of 97%
#
# ## And for the tesst dataset R2 score is of 85%
